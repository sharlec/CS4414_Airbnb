# %%
import numpy as np
import pandas as pd
from wordcloud import WordCloud

# %%
dataset  = pd.read_csv('cleanData.csv')

# %%
dataset.hist(column="needsIndex")
plt.xlabel("houses",fontsize=15)
plt.ylabel("needsIndex",fontsize=15)
plt.xlim([0.0,2.0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9fc2ae145298> in <module>()
#       1 dataset.hist(column="needsIndex")
# ----> 2 plt.xlabel("houses",fontsize=15)
#       3 plt.ylabel("needsIndex",fontsize=15)
#       4 plt.xlim([0.0,2.0])
#
# NameError: name 'plt' is not defined

# %%
dataset
# Out:
#        host_since  host_identity_verified            neighbourhood  \
# 0      2008-08-08                    True          Little Portugal
# 1      2009-06-22                   False             Harbourfront
# 2      2009-09-01                    True                Riverdale
# 3      2009-10-25                    True                The Annex
# 4      2010-03-15                    True                 Fairbank
# 5      2010-04-25                    True   Entertainment District
# 6      2010-05-04                    True        Greenwood-Coxwell
# 7      2010-03-01                   False               Davisville
# 8      2009-06-22                   False             Harbourfront
# 9      2010-07-20                   False                 Parkdale
# 10     2010-07-28                    True                 Oakridge
# 11     2010-08-01                    True   Entertainment District
# 12     2010-08-05                    True         Wexford/Maryvale
# ...

# %%
raw_data  = pd.read_csv('listings.csv')
raw_data['price']
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (88) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0        469.0
# 1         97.0
# 2         69.0
# 3         65.0
# 4         70.0
# 5        199.0
# 6         54.0
# 7         85.0
# 8        129.0
# 9        125.0
# 10        75.0
# 11       135.0
# 12       110.0
# 13       131.0
# 14       120.0
# 15       147.0
# 16       120.0
# 17       110.0
# 18       160.0
# 19        80.0
# 20       150.0
# 21       316.0
# 22        88.0
# 23        56.0
# 24       160.0
# 25        94.0
# 26       145.0
# 27       145.0
# 28       120.0
# 29        59.0
#          ...
# 17313    110.0
# 17314    450.0
# 17315    195.0
# 17316    125.0
# 17317     45.0
# 17318    150.0
# 17319    350.0
# 17320    400.0
# 17321    102.0
# 17322    150.0
# 17323    450.0
# 17324    102.0
# 17325     94.0
# ...

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
wordcloud= WordCloud(background_color="white",width=1000, height=860, margin=2).generate(raw_data['name'].str.cat())
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
raw_data['words'] = raw_data['name'] + raw_data['summary'] + raw_data['description'] + raw_data['space']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np

def get_mask():
    x,y = np.ogrid[:300,:300]
    mask = (x-150) ** 2 + (y-150) ** 2 > 130 ** 2
    mask = 255 * mask.astype(int)
    return mask

if __name__ == "__main__":
    #每个词的权重
    text = {"first":0.1,"second":0.2,"third":0.3,"fourth":0.4,"fifth":0.5}
    wc = WordCloud(background_color="white",mask=get_mask())
    wc.generate_from_frequencies(text)
    plt.axis("off")
    plt.imshow(wc,interpolation="bilinear")
    plt.show()

# %%
text = raw_data['words'].str.cat()
df_out = text.strip('.').split(' ')
def byebye(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]

my_list = byebye(df_out)
my_list
# Out:
# ['Beautiful',
#  'home',
#  'in',
#  'amazing',
#  'area!This',
#  'large,',
#  'family',
#  'is',
#  'located',
#  'one',
#  'of',
#  "Toronto's",
#  'most',
#  'vibrant',
#  'downtown',
#  'neighbourhoods.',
#  'The',
#  'five-bedroom,',
#  'three-bath',
#  'house',
#  'newly',
#  'renovated',
#  'and',
#  'complete',
#  'with',
#  'all',
#  'the',
#  'amenities',
#  "you'll",
#  'need',
#  'for',
#  'a',
#  'fabulous',
#  'time',
#  'city.This',
#  'city.',
#  'Visit',
#  'Toronto',
#  'this',
#  'furnished',
#  'as',
#  'your',
#  'base!',
#  'This',
#  'lovely',
#  'surrounded',
#  'by',
#  'gardens',
#  'back',
#  'front.',
#  'Inside,',
#  'find',
#  'large',
#  'open',
#  'space',
#  'modern',
#  'kitchen',
#  'bright',
#  'living',
#  'dining',
#  'room.',
#  'There',
#  'are',
#  'two',
#  'floors',
#  'up',
#  '-',
#  'master',
#  'bedroom',
#  'king-size',
#  'bed',
#  'kids',
#  'rooms,',
#  'each',
#  'single',
#  'bed.',
#  'attic',
#  'private',
#  'king-sized',
# ...

# %%
import math
w_l = len(raw_data['words'])
l_l = len(my_list)
raw_data['words'].fillna(value =' ')
raw_data['words']  
# prices = raw_data['price']
# type(prices)
weight={}

for i in range(0,l_l):
    current = my_list[i]
    type(current)
    price_sum = 0
    count = 0
    for j in range(0,w_l):
        if type(raw_data['words'][j])!=float:
            if raw_data['words'][j].find(current):
                count = count + 1
                price_sum = price_sum + prices[j]
    print(current)
    print(i)
    if count!=0:
        weight[current] = price_sum/count
    else:
        weight[current] = 0
# Out:
# Beautiful
# 0
# home
# 1
# in
# 2
# amazing
# 3
# area!This
# 4
# large,
# 5
# family
# 6
# is
# 7
# located
# 8
# one
# 9
# of
# 10
# Toronto's
# 11
# most
# 12
# vibrant
# 13
# downtown
# 14
# neighbourhoods.
# 15
# The
# 16
# five-bedroom,
# 17
# three-bath
# 18
# house
# 19
# newly
# 20
# renovated
# 21
# and
# 22
# complete
# 23
# with
# 24
# all
# 25
# the
# 26
# amenities
# 27
# you'll
# 28
# need
# 29
# for
# 30
# a
# 31
# fabulous
# 32
# time
# 33
# city.This
# 34
# city.
# 35
# Visit
# 36
# Toronto
# 37
# this
# 38
# furnished
# 39
# as
# 40
# your
# 41
# base!
# 42
# This
# 43
# lovely
# 44
# surrounded
# 45
# by
# 46
# gardens
# 47
# back
# 48
# front.
# 49
# Inside,
# 50
# find
# 51
# large
# 52
# open
# 53
# space
# 54
# modern
# 55
# kitchen
# 56
# bright
# 57
# living
# 58
# dining
# 59
# room.
# 60
# There
# 61
# are
# 62
# two
# 63
# floors
# 64
# up
# 65
# -
# 66
# master
# 67
# bedroom
# 68
# king-size
# 69
# bed
# 70
# kids
# 71
# rooms,
# 72
# each
# 73
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
weight['home']
# def get_mask():
#     x,y = np.ogrid[:300,:300]
#     mask = (x-150) ** 2 + (y-150) ** 2 > 130 ** 2
#     mask = 255 * mask.astype(int)
#     return mask

if __name__ == "__main__":
    #每个词的权重
    wc = WordCloud(background_color="white",width=1000, height=860, margin=2)
    wc.generate_from_frequencies(weight)
    plt.axis("off")
    plt.imshow(wc,interpolation="bilinear")
    plt.show()
